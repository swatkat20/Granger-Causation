# %%
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from datetime import datetime, timedelta
from statsmodels.tsa.api import VAR 
import warnings
warnings.filterwarnings("ignore")

def get_max_diff(timeseries):
    diff_count = 0
    while True:
        result = adfuller(timeseries.dropna())
        p_value = result[1]
        print(f"Attempt {diff_count}: ADF Statistic = {result[0]}, p-value = {p_value}")
        if p_value <= 0.05:
            print("Series is now stationary.")
            return diff_count
        timeseries = timeseries.diff().dropna()
        diff_count += 1
    return diff_count

def diff_n_times(series_a, series_b, n):
    for _ in range(n):
        series_a = series_a.diff().dropna()
        series_b = series_b.diff().dropna()
    return series_a, series_b

def get_optimal_lag(data):
    max_lag = min(len(data) // 2, 15)
    aic_values = []
    for lag in range(1, max_lag + 1):
        model = VAR(data)
        results = model.fit(lag)
        aic_values.append(results.aic)
    return aic_values.index(min(aic_values)) + 1

# Master list to collect all results
all_results = []

def run_granger_analysis(day_range):
    print(f"\n{'='*30} Running for last {day_range} days {'='*30}")
    
    groupA = ["AAPL", "GOOG", "MSFT", "NVDA", "META", "AMZN", "TSLA"]
    groupB = ["BBAI", "SOUN", "QUBT", "OKLO", "RKLB", "AI", "AKAM"]
    stocks = groupA + groupB
    
    end_date = datetime(2025,4,28)
    start_date = end_date - timedelta(days=day_range)
    
    data = yf.download(stocks, start=start_date, end=end_date, interval="1h")["High"].reset_index(drop=True)
    
    max_diff_per_stock = {}
    for stock in stocks:
        print(f"\nChecking maximum differencing for {stock}...")
        max_diff_per_stock[stock] = get_max_diff(data[stock])
    
    for stock_a in groupA:
        for stock_b in groupB:
            print(f"\nGranger Causality test between {stock_a} and {stock_b}:")

            series_a, series_b = diff_n_times(
                data[stock_a], data[stock_b],
                max(max_diff_per_stock[stock_a], max_diff_per_stock[stock_b])
            )

            if len(series_a) == 0 or len(series_b) == 0:
                print(f"Skipping {stock_a} vs {stock_b} due to empty series.")
                continue

            # Test A causes B
            diff_data_ab = pd.DataFrame({stock_b: series_b, stock_a: series_a}).dropna()
            optimal_lag = get_optimal_lag(diff_data_ab)
            granger_result_ab = grangercausalitytests(diff_data_ab, [optimal_lag], verbose=False)
            p_ab = granger_result_ab[optimal_lag][0]['ssr_ftest'][1]

            # Test B causes A
            diff_data_ba = pd.DataFrame({stock_a: series_a, stock_b: series_b}).dropna()
            optimal_lag = get_optimal_lag(diff_data_ba)
            granger_result_ba = grangercausalitytests(diff_data_ba, [optimal_lag], verbose=False)
            p_ba = granger_result_ba[optimal_lag][0]['ssr_ftest'][1]

            # Append results to global list
            all_results.append({
                "Days": day_range,
                "Stock_A": stock_a,
                "Stock_B": stock_b,
                "Optimal_Lag": optimal_lag,
                "P_Value_A_to_B": round(p_ab, 4),
                "Causal_A_to_B": "Yes" if p_ab < 0.05 else "No",
                "P_Value_B_to_A": round(p_ba, 4),
                "Causal_B_to_A": "Yes" if p_ba < 0.05 else "No"
            })

# Run the analysis for multiple day ranges
day_ranges = [30, 60, 90, 180, 360, 720]
for days in day_ranges:
    run_granger_analysis(days)

# Save all results into one CSV file
all_results_df = pd.DataFrame(all_results)
all_results_df.to_csv("all_granger_results.csv", index=False)
print("\n✅ All results saved to 'all_granger_results.csv'")
# Out:
# ============================== Running for last 30 days ==============================
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  14 of 14 completed
# Checking maximum differencing for AAPL...
# Attempt 0: ADF Statistic = -1.781085832464729, p-value = 0.3898916565525684
# Attempt 1: ADF Statistic = -11.285198800761595, p-value = 1.4237333661747784e-20
# Series is now stationary.
#
# Checking maximum differencing for GOOG...
# Attempt 0: ADF Statistic = -2.033082025526113, p-value = 0.27225874829682783
# Attempt 1: ADF Statistic = -11.522610784509283, p-value = 4.0061198075340634e-21
# Series is now stationary.
#
# Checking maximum differencing for MSFT...
# Attempt 0: ADF Statistic = -1.610575319667589, p-value = 0.47767362460909585
# Attempt 1: ADF Statistic = -4.598574011444424, p-value = 0.00012995363157943391
# Series is now stationary.
#
# Checking maximum differencing for NVDA...
# Attempt 0: ADF Statistic = -2.2457887215645993, p-value = 0.19004826726600754
# Attempt 1: ADF Statistic = -4.728316550943215, p-value = 7.442787968633953e-05
# Series is now stationary.
#
# Checking maximum differencing for META...
# Attempt 0: ADF Statistic = -2.120904391466736, p-value = 0.23619233938120032
# Attempt 1: ADF Statistic = -10.396719402715465, p-value = 1.9565613266275314e-18
# Series is now stationary.
#
# Checking maximum differencing for AMZN...
# Attempt 0: ADF Statistic = -2.359653470082256, p-value = 0.1534491114455977
# Attempt 1: ADF Statistic = -4.558202763280537, p-value = 0.00015412952861835276
# Series is now stationary.
#
# Checking maximum differencing for TSLA...
# Attempt 0: ADF Statistic = -1.5027516389640316, p-value = 0.5321497059392926
# Attempt 1: ADF Statistic = -4.446731870186278, p-value = 0.0002451314454315486
# Series is now stationary.
#
# Checking maximum differencing for BBAI...
# Attempt 0: ADF Statistic = -0.8217837591568501, p-value = 0.8126393625209904
# Attempt 1: ADF Statistic = -4.0761080411665045, p-value = 0.0010604427624409864
# Series is now stationary.
#
# Checking maximum differencing for SOUN...
# Attempt 0: ADF Statistic = -0.7037244129895577, p-value = 0.8457824708838064
# Attempt 1: ADF Statistic = -4.852112069488809, p-value = 4.3185585088292886e-05
# Series is now stationary.
#
# Checking maximum differencing for QUBT...
# Attempt 0: ADF Statistic = -2.3841286925639347, p-value = 0.14626616506135326
# Attempt 1: ADF Statistic = -4.4075641580188165, p-value = 0.000287815549160284
# Series is now stationary.
#
# Checking maximum differencing for OKLO...
# Attempt 0: ADF Statistic = -3.149358410134661, p-value = 0.023109605713429363
# Series is now stationary.
#
# Checking maximum differencing for RKLB...
# Attempt 0: ADF Statistic = -1.0182388746194286, p-value = 0.7465541026159319
# Attempt 1: ADF Statistic = -4.792364343309659, p-value = 5.624493563428156e-05
# Series is now stationary.
#
# Checking maximum differencing for AI...
# Attempt 0: ADF Statistic = -1.3002319134093667, p-value = 0.6290662063357004
# Attempt 1: ADF Statistic = -4.52572905917341, p-value = 0.00017662834166137307
# Series is now stationary.
#
# Checking maximum differencing for AKAM...
# Attempt 0: ADF Statistic = -1.5463177512833428, p-value = 0.510487000000356
# Attempt 1: ADF Statistic = -4.0430198221259905, p-value = 0.0012012646200749396
# Series is now stationary.
#
# Granger Causality test between AAPL and BBAI:
#
# Granger Causality test between AAPL and SOUN:
#
# Granger Causality test between AAPL and QUBT:
#
# Granger Causality test between AAPL and OKLO:
#
# Granger Causality test between AAPL and RKLB:
#
# Granger Causality test between AAPL and AI:
#
# Granger Causality test between AAPL and AKAM:
#
# Granger Causality test between GOOG and BBAI:
#
# Granger Causality test between GOOG and SOUN:
#
# Granger Causality test between GOOG and QUBT:
#
# Granger Causality test between GOOG and OKLO:
#
# Granger Causality test between GOOG and RKLB:
#
# Granger Causality test between GOOG and AI:
#
# Granger Causality test between GOOG and AKAM:
#
# Granger Causality test between MSFT and BBAI:
#
# Granger Causality test between MSFT and SOUN:
#
# Granger Causality test between MSFT and QUBT:
#
# Granger Causality test between MSFT and OKLO:
#
# Granger Causality test between MSFT and RKLB:
#
# Granger Causality test between MSFT and AI:
#
# Granger Causality test between MSFT and AKAM:
#
# Granger Causality test between NVDA and BBAI:
#
# Granger Causality test between NVDA and SOUN:
#
# Granger Causality test between NVDA and QUBT:
#
# Granger Causality test between NVDA and OKLO:
#
# Granger Causality test between NVDA and RKLB:
#
# Granger Causality test between NVDA and AI:
#
# Granger Causality test between NVDA and AKAM:
#
# Granger Causality test between META and BBAI:
#
# Granger Causality test between META and SOUN:
#
# Granger Causality test between META and QUBT:
#
# Granger Causality test between META and OKLO:
#
# Granger Causality test between META and RKLB:
#
# Granger Causality test between META and AI:
#
# Granger Causality test between META and AKAM:
#
# Granger Causality test between AMZN and BBAI:
#
# Granger Causality test between AMZN and SOUN:
#
# Granger Causality test between AMZN and QUBT:
#
# Granger Causality test between AMZN and OKLO:
#
# Granger Causality test between AMZN and RKLB:
#
# Granger Causality test between AMZN and AI:
#
# Granger Causality test between AMZN and AKAM:
#
# Granger Causality test between TSLA and BBAI:
#
# Granger Causality test between TSLA and SOUN:
#
# Granger Causality test between TSLA and QUBT:
#
# Granger Causality test between TSLA and OKLO:
#
# Granger Causality test between TSLA and RKLB:
#
# Granger Causality test between TSLA and AI:
#
# Granger Causality test between TSLA and AKAM:
#
# ============================== Running for last 60 days ==============================
# [*********************100%***********************]  14 of 14 completed
# Checking maximum differencing for AAPL...
# Attempt 0: ADF Statistic = -1.7584499262832298, p-value = 0.40127639305411744
# Attempt 1: ADF Statistic = -8.082441977532183, p-value = 1.4492484150162045e-12
# Series is now stationary.
#
# Checking maximum differencing for GOOG...
# Attempt 0: ADF Statistic = -1.889682537183095, p-value = 0.3369302288738906
# Attempt 1: ADF Statistic = -15.859822387771999, p-value = 9.2398284531186e-29
# Series is now stationary.
#
# Checking maximum differencing for MSFT...
# Attempt 0: ADF Statistic = -2.9212134442335116, p-value = 0.04293619065926928
# Series is now stationary.
#
# Checking maximum differencing for NVDA...
# Attempt 0: ADF Statistic = -2.2720200036925777, p-value = 0.18115090484977975
# Attempt 1: ADF Statistic = -6.68419682833227, p-value = 4.266835115138362e-09
# Series is now stationary.
#
# Checking maximum differencing for META...
# Attempt 0: ADF Statistic = -1.987627094686228, p-value = 0.29202439876972763
# Attempt 1: ADF Statistic = -6.496881710353983, p-value = 1.188215498125672e-08
# Series is now stationary.
#
# Checking maximum differencing for AMZN...
# Attempt 0: ADF Statistic = -2.012040238672304, p-value = 0.28131895482957947
# Attempt 1: ADF Statistic = -6.764280250938117, p-value = 2.742223398153181e-09
# Series is now stationary.
#
# Checking maximum differencing for TSLA...
# Attempt 0: ADF Statistic = -2.783015337085481, p-value = 0.06074116284112996
# Attempt 1: ADF Statistic = -6.400545442691452, p-value = 2.0005787097641553e-08
# Series is now stationary.
#
# Checking maximum differencing for BBAI...
# Attempt 0: ADF Statistic = -3.050175251698347, p-value = 0.030466984539993844
# Series is now stationary.
#
# Checking maximum differencing for SOUN...
# Attempt 0: ADF Statistic = -2.538166894506057, p-value = 0.10646186955646136
# Attempt 1: ADF Statistic = -7.3505949382564495, p-value = 1.0084031806779518e-10
# Series is now stationary.
#
# Checking maximum differencing for QUBT...
# Attempt 0: ADF Statistic = -2.0187332896695196, p-value = 0.27842008718785727
# Attempt 1: ADF Statistic = -4.373122417502824, p-value = 0.0003310868470663485
# Series is now stationary.
#
# Checking maximum differencing for OKLO...
# Attempt 0: ADF Statistic = -2.83751190313966, p-value = 0.0531120172377889
# Attempt 1: ADF Statistic = -16.438687687944046, p-value = 2.439491951577237e-29
# Series is now stationary.
#
# Checking maximum differencing for RKLB...
# Attempt 0: ADF Statistic = -2.617191586995921, p-value = 0.08949591621794711
# Attempt 1: ADF Statistic = -17.54808755564514, p-value = 4.156042858260963e-30
# Series is now stationary.
#
# Checking maximum differencing for AI...
# Attempt 0: ADF Statistic = -2.263301413287094, p-value = 0.18407721637543972
# Attempt 1: ADF Statistic = -6.912322296975257, p-value = 1.2035601624299576e-09
# Series is now stationary.
#
# Checking maximum differencing for AKAM...
# Attempt 0: ADF Statistic = -1.7029842335399403, p-value = 0.4295755696048562
# Attempt 1: ADF Statistic = -6.171375879149019, p-value = 6.792321391832312e-08
# Series is now stationary.
#
# Granger Causality test between AAPL and BBAI:
#
# Granger Causality test between AAPL and SOUN:
#
# Granger Causality test between AAPL and QUBT:
#
# Granger Causality test between AAPL and OKLO:
#
# Granger Causality test between AAPL and RKLB:
#
# Granger Causality test between AAPL and AI:
#
# Granger Causality test between AAPL and AKAM:
#
# Granger Causality test between GOOG and BBAI:
#
# Granger Causality test between GOOG and SOUN:
#
# Granger Causality test between GOOG and QUBT:
#
# Granger Causality test between GOOG and OKLO:
#
# Granger Causality test between GOOG and RKLB:
#
# Granger Causality test between GOOG and AI:
#
# Granger Causality test between GOOG and AKAM:
#
# Granger Causality test between MSFT and BBAI:
#
# Granger Causality test between MSFT and SOUN:
#
# Granger Causality test between MSFT and QUBT:
#
# Granger Causality test between MSFT and OKLO:
#
# Granger Causality test between MSFT and RKLB:
#
# Granger Causality test between MSFT and AI:
#
# Granger Causality test between MSFT and AKAM:
#
# Granger Causality test between NVDA and BBAI:
#
# Granger Causality test between NVDA and SOUN:
#
# Granger Causality test between NVDA and QUBT:
#
# Granger Causality test between NVDA and OKLO:
#
# Granger Causality test between NVDA and RKLB:
#
# Granger Causality test between NVDA and AI:
#
# Granger Causality test between NVDA and AKAM:
#
# Granger Causality test between META and BBAI:
#
# Granger Causality test between META and SOUN:
#
# Granger Causality test between META and QUBT:
#
# Granger Causality test between META and OKLO:
#
# Granger Causality test between META and RKLB:
#
# Granger Causality test between META and AI:
#
# Granger Causality test between META and AKAM:
#
# Granger Causality test between AMZN and BBAI:
#
# Granger Causality test between AMZN and SOUN:
#
# Granger Causality test between AMZN and QUBT:
#
# Granger Causality test between AMZN and OKLO:
#
# Granger Causality test between AMZN and RKLB:
#
# Granger Causality test between AMZN and AI:
#
# Granger Causality test between AMZN and AKAM:
#
# Granger Causality test between TSLA and BBAI:
#
# Granger Causality test between TSLA and SOUN:
#
# Granger Causality test between TSLA and QUBT:
#
# Granger Causality test between TSLA and OKLO:
#
# Granger Causality test between TSLA and RKLB:
#
# Granger Causality test between TSLA and AI:
#
# Granger Causality test between TSLA and AKAM:
#
# ============================== Running for last 90 days ==============================
# [*********************100%***********************]  14 of 14 completed
# Checking maximum differencing for AAPL...
# Attempt 0: ADF Statistic = -1.2367929780790652, p-value = 0.6575715103692713
# Attempt 1: ADF Statistic = -9.756962888935547, p-value = 7.743405640931824e-17
# Series is now stationary.
#
# Checking maximum differencing for GOOG...
# Attempt 0: ADF Statistic = -1.6764081883350759, p-value = 0.44330683564024426
# Attempt 1: ADF Statistic = -9.571589998168262, p-value = 2.2805991919228824e-16
# Series is now stationary.
#
# Checking maximum differencing for MSFT...
# Attempt 0: ADF Statistic = -2.116600776192431, p-value = 0.23789195125730683
# Attempt 1: ADF Statistic = -6.558165635351132, p-value = 8.512569487166703e-09
# Series is now stationary.
#
# Checking maximum differencing for NVDA...
# Attempt 0: ADF Statistic = -1.4662691173564784, p-value = 0.550126681998717
# Attempt 1: ADF Statistic = -21.266489573183165, p-value = 0.0
# Series is now stationary.
#
# Checking maximum differencing for META...
# Attempt 0: ADF Statistic = -0.9421392391092874, p-value = 0.7737789265032156
# Attempt 1: ADF Statistic = -8.075976401286553, p-value = 1.505180032348573e-12
# Series is now stationary.
#
# Checking maximum differencing for AMZN...
# Attempt 0: ADF Statistic = -1.4355552364389768, p-value = 0.565116848789094
# Attempt 1: ADF Statistic = -8.592149308480895, p-value = 7.237512542032497e-14
# Series is now stationary.
#
# Checking maximum differencing for TSLA...
# Attempt 0: ADF Statistic = -2.376736415311972, p-value = 0.14841031417869904
# Attempt 1: ADF Statistic = -7.6361026194919415, p-value = 1.9505859695787014e-11
# Series is now stationary.
#
# Checking maximum differencing for BBAI...
# Attempt 0: ADF Statistic = -1.2465556536270517, p-value = 0.6532550997982276
# Attempt 1: ADF Statistic = -4.242056715396839, p-value = 0.0005588318076195136
# Series is now stationary.
#
# Checking maximum differencing for SOUN...
# Attempt 0: ADF Statistic = -1.5704354483854532, p-value = 0.498425540790643
# Attempt 1: ADF Statistic = -8.753390033311046, p-value = 2.7971341591410972e-14
# Series is now stationary.
#
# Checking maximum differencing for QUBT...
# Attempt 0: ADF Statistic = -2.7242862901364777, p-value = 0.06992913869345942
# Attempt 1: ADF Statistic = -5.2348768961225005, p-value = 7.459417366440104e-06
# Series is now stationary.
#
# Checking maximum differencing for OKLO...
# Attempt 0: ADF Statistic = -1.1996808964632943, p-value = 0.6737329671502469
# Attempt 1: ADF Statistic = -4.692749853609444, p-value = 8.68318056096654e-05
# Series is now stationary.
#
# Checking maximum differencing for RKLB...
# Attempt 0: ADF Statistic = -1.701747720155989, p-value = 0.4302122245816573
# Attempt 1: ADF Statistic = -9.022622236450067, p-value = 5.720914585963594e-15
# Series is now stationary.
#
# Checking maximum differencing for AI...
# Attempt 0: ADF Statistic = -1.3671712269827372, p-value = 0.5979095770167348
# Attempt 1: ADF Statistic = -7.91445348035131, p-value = 3.869608521277759e-12
# Series is now stationary.
#
# Checking maximum differencing for AKAM...
# Attempt 0: ADF Statistic = -1.6895380767798815, p-value = 0.4365106755865336
# Attempt 1: ADF Statistic = -15.358859682145301, p-value = 3.6354837730166822e-28
# Series is now stationary.
#
# Granger Causality test between AAPL and BBAI:
#
# Granger Causality test between AAPL and SOUN:
#
# Granger Causality test between AAPL and QUBT:
#
# Granger Causality test between AAPL and OKLO:
#
# Granger Causality test between AAPL and RKLB:
#
# Granger Causality test between AAPL and AI:
#
# Granger Causality test between AAPL and AKAM:
#
# Granger Causality test between GOOG and BBAI:
#
# Granger Causality test between GOOG and SOUN:
#
# Granger Causality test between GOOG and QUBT:
#
# Granger Causality test between GOOG and OKLO:
#
# Granger Causality test between GOOG and RKLB:
#
# Granger Causality test between GOOG and AI:
#
# Granger Causality test between GOOG and AKAM:
#
# Granger Causality test between MSFT and BBAI:
#
# Granger Causality test between MSFT and SOUN:
#
# Granger Causality test between MSFT and QUBT:
#
# Granger Causality test between MSFT and OKLO:
#
# Granger Causality test between MSFT and RKLB:
#
# Granger Causality test between MSFT and AI:
#
# Granger Causality test between MSFT and AKAM:
#
# Granger Causality test between NVDA and BBAI:
#
# Granger Causality test between NVDA and SOUN:
#
# Granger Causality test between NVDA and QUBT:
#
# Granger Causality test between NVDA and OKLO:
#
# Granger Causality test between NVDA and RKLB:
#
# Granger Causality test between NVDA and AI:
#
# Granger Causality test between NVDA and AKAM:
#
# Granger Causality test between META and BBAI:
#
# Granger Causality test between META and SOUN:
#
# Granger Causality test between META and QUBT:
#
# Granger Causality test between META and OKLO:
#
# Granger Causality test between META and RKLB:
#
# Granger Causality test between META and AI:
#
# Granger Causality test between META and AKAM:
#
# Granger Causality test between AMZN and BBAI:
#
# Granger Causality test between AMZN and SOUN:
#
# Granger Causality test between AMZN and QUBT:
#
# Granger Causality test between AMZN and OKLO:
#
# Granger Causality test between AMZN and RKLB:
#
# Granger Causality test between AMZN and AI:
#
# Granger Causality test between AMZN and AKAM:
#
# Granger Causality test between TSLA and BBAI:
#
# Granger Causality test between TSLA and SOUN:
#
# Granger Causality test between TSLA and QUBT:
#
# Granger Causality test between TSLA and OKLO:
#
# Granger Causality test between TSLA and RKLB:
#
# Granger Causality test between TSLA and AI:
#
# Granger Causality test between TSLA and AKAM:
#
# ============================== Running for last 180 days ==============================
# [*********************100%***********************]  14 of 14 completed
# Checking maximum differencing for AAPL...
# Attempt 0: ADF Statistic = -1.3472499115563519, p-value = 0.607287978517753
# Attempt 1: ADF Statistic = -10.982665282594972, p-value = 7.391277946969822e-20
# Series is now stationary.
#
# Checking maximum differencing for GOOG...
# Attempt 0: ADF Statistic = -1.182916038379399, p-value = 0.6809012902364383
# Attempt 1: ADF Statistic = -9.957974651844253, p-value = 2.4156464576909826e-17
# Series is now stationary.
#
# Checking maximum differencing for MSFT...
# Attempt 0: ADF Statistic = -1.5699809537566356, p-value = 0.49865319695974114
# Attempt 1: ADF Statistic = -26.57090149225406, p-value = 0.0
# Series is now stationary.
#
# Checking maximum differencing for NVDA...
# Attempt 0: ADF Statistic = -1.459581936137465, p-value = 0.553402497930744
# Attempt 1: ADF Statistic = -19.78575720929928, p-value = 0.0
# Series is now stationary.
#
# Checking maximum differencing for META...
# Attempt 0: ADF Statistic = -1.6147664886408373, p-value = 0.4754740713284508
# Attempt 1: ADF Statistic = -5.320392361071202, p-value = 4.967456740733541e-06
# Series is now stationary.
#
# Checking maximum differencing for AMZN...
# Attempt 0: ADF Statistic = -1.0040573677593003, p-value = 0.7517815943854609
# Attempt 1: ADF Statistic = -10.95373629216931, p-value = 8.666810274448497e-20
# Series is now stationary.
#
# Checking maximum differencing for TSLA...
# Attempt 0: ADF Statistic = -1.6513329101145162, p-value = 0.4563453655313745
# Attempt 1: ADF Statistic = -5.190617548886051, p-value = 9.188260010482199e-06
# Series is now stationary.
#
# Checking maximum differencing for BBAI...
# Attempt 0: ADF Statistic = -2.333985002693679, p-value = 0.16124123376246824
# Attempt 1: ADF Statistic = -4.387256972863632, p-value = 0.00031263165958641783
# Series is now stationary.
#
# Checking maximum differencing for SOUN...
# Attempt 0: ADF Statistic = -1.9204161451599513, p-value = 0.322518499364961
# Attempt 1: ADF Statistic = -6.14658201199689, p-value = 7.74099349451894e-08
# Series is now stationary.
#
# Checking maximum differencing for QUBT...
# Attempt 0: ADF Statistic = -2.532608075830789, p-value = 0.10774064178422343
# Attempt 1: ADF Statistic = -7.686750797083126, p-value = 1.454771713371854e-11
# Series is now stationary.
#
# Checking maximum differencing for OKLO...
# Attempt 0: ADF Statistic = -1.7973569144830719, p-value = 0.38177469954212506
# Attempt 1: ADF Statistic = -5.994285034312204, p-value = 1.7162785908304488e-07
# Series is now stationary.
#
# Checking maximum differencing for RKLB...
# Attempt 0: ADF Statistic = -2.555023766732697, p-value = 0.10265371679717777
# Attempt 1: ADF Statistic = -5.759538959490092, p-value = 5.714824479620965e-07
# Series is now stationary.
#
# Checking maximum differencing for AI...
# Attempt 0: ADF Statistic = -1.0213470372107023, p-value = 0.7453990583062695
# Attempt 1: ADF Statistic = -10.7201512950893, p-value = 3.1661171137433723e-19
# Series is now stationary.
#
# Checking maximum differencing for AKAM...
# Attempt 0: ADF Statistic = -1.7002828219295953, p-value = 0.4309667643954717
# Attempt 1: ADF Statistic = -9.501425448925092, p-value = 3.436877920334113e-16
# Series is now stationary.
#
# Granger Causality test between AAPL and BBAI:
#
# Granger Causality test between AAPL and SOUN:
#
# Granger Causality test between AAPL and QUBT:
#
# Granger Causality test between AAPL and OKLO:
#
# Granger Causality test between AAPL and RKLB:
#
# Granger Causality test between AAPL and AI:
#
# Granger Causality test between AAPL and AKAM:
#
# Granger Causality test between GOOG and BBAI:
#
# Granger Causality test between GOOG and SOUN:
#
# Granger Causality test between GOOG and QUBT:
#
# Granger Causality test between GOOG and OKLO:
#
# Granger Causality test between GOOG and RKLB:
#
# Granger Causality test between GOOG and AI:
#
# Granger Causality test between GOOG and AKAM:
#
# Granger Causality test between MSFT and BBAI:
#
# Granger Causality test between MSFT and SOUN:
#
# Granger Causality test between MSFT and QUBT:
#
# Granger Causality test between MSFT and OKLO:
#
# Granger Causality test between MSFT and RKLB:
#
# Granger Causality test between MSFT and AI:
#
# Granger Causality test between MSFT and AKAM:
#
# Granger Causality test between NVDA and BBAI:
#
# Granger Causality test between NVDA and SOUN:
#
# Granger Causality test between NVDA and QUBT:
#
# Granger Causality test between NVDA and OKLO:
#
# Granger Causality test between NVDA and RKLB:
#
# Granger Causality test between NVDA and AI:
#
# Granger Causality test between NVDA and AKAM:
#
# Granger Causality test between META and BBAI:
#
# Granger Causality test between META and SOUN:
#
# Granger Causality test between META and QUBT:
#
# Granger Causality test between META and OKLO:
#
# Granger Causality test between META and RKLB:
#
# Granger Causality test between META and AI:
#
# Granger Causality test between META and AKAM:
#
# Granger Causality test between AMZN and BBAI:
#
# Granger Causality test between AMZN and SOUN:
#
# Granger Causality test between AMZN and QUBT:
#
# Granger Causality test between AMZN and OKLO:
#
# Granger Causality test between AMZN and RKLB:
#
# Granger Causality test between AMZN and AI:
#
# Granger Causality test between AMZN and AKAM:
#
# Granger Causality test between TSLA and BBAI:
#
# Granger Causality test between TSLA and SOUN:
#
# Granger Causality test between TSLA and QUBT:
#
# Granger Causality test between TSLA and OKLO:
#
# Granger Causality test between TSLA and RKLB:
#
# Granger Causality test between TSLA and AI:
#
# Granger Causality test between TSLA and AKAM:
#
# ============================== Running for last 360 days ==============================
# [*********************100%***********************]  14 of 14 completed
# Checking maximum differencing for AAPL...
# Attempt 0: ADF Statistic = -2.538093740748357, p-value = 0.10647862384304785
# Attempt 1: ADF Statistic = -15.121264221190218, p-value = 7.45429958302826e-28
# Series is now stationary.
#
# Checking maximum differencing for GOOG...
# Attempt 0: ADF Statistic = -2.019115045230883, p-value = 0.278255217228779
# Attempt 1: ADF Statistic = -10.101324196628946, p-value = 1.0576117587994333e-17
# Series is now stationary.
#
# Checking maximum differencing for MSFT...
# Attempt 0: ADF Statistic = -1.9868693922780587, p-value = 0.2923599237321233
# Attempt 1: ADF Statistic = -14.962754047122548, p-value = 1.2326188699322497e-27
# Series is now stationary.
#
# Checking maximum differencing for NVDA...
# Attempt 0: ADF Statistic = -2.8642931963347484, p-value = 0.049660561207900224
# Series is now stationary.
#
# Checking maximum differencing for META...
# Attempt 0: ADF Statistic = -1.792460935925799, p-value = 0.3842110014021131
# Attempt 1: ADF Statistic = -8.104682523056551, p-value = 1.2722022478276735e-12
# Series is now stationary.
#
# Checking maximum differencing for AMZN...
# Attempt 0: ADF Statistic = -1.4929175549221438, p-value = 0.5370119685114151
# Attempt 1: ADF Statistic = -11.088892980590128, p-value = 4.129721417628847e-20
# Series is now stationary.
#
# Checking maximum differencing for TSLA...
# Attempt 0: ADF Statistic = -1.6031658324930975, p-value = 0.4820029847335135
# Attempt 1: ADF Statistic = -7.9715356614434105, p-value = 2.7728239401861864e-12
# Series is now stationary.
#
# Checking maximum differencing for BBAI...
# Attempt 0: ADF Statistic = -2.292958940696974, p-value = 0.1742489103480621
# Attempt 1: ADF Statistic = -6.391530400923575, p-value = 2.1000905763654796e-08
# Series is now stationary.
#
# Checking maximum differencing for SOUN...
# Attempt 0: ADF Statistic = -1.6473203253394821, p-value = 0.4584383266148596
# Attempt 1: ADF Statistic = -8.903063439974408, p-value = 1.1573087373191036e-14
# Series is now stationary.
#
# Checking maximum differencing for QUBT...
# Attempt 0: ADF Statistic = -1.7375902299780357, p-value = 0.4118562795286754
# Attempt 1: ADF Statistic = -9.561824044786876, p-value = 2.4144784803587805e-16
# Series is now stationary.
#
# Checking maximum differencing for OKLO...
# Attempt 0: ADF Statistic = -1.3670226518275164, p-value = 0.597979835217782
# Attempt 1: ADF Statistic = -8.584193096662295, p-value = 7.585016971056871e-14
# Series is now stationary.
#
# Checking maximum differencing for RKLB...
# Attempt 0: ADF Statistic = -0.9581951384952524, p-value = 0.7682048026556381
# Attempt 1: ADF Statistic = -8.574483830079389, p-value = 8.031753201981893e-14
# Series is now stationary.
#
# Checking maximum differencing for AI...
# Attempt 0: ADF Statistic = -1.5578489715952577, p-value = 0.5047252329161895
# Attempt 1: ADF Statistic = -8.925668185304035, p-value = 1.012934780125615e-14
# Series is now stationary.
#
# Checking maximum differencing for AKAM...
# Attempt 0: ADF Statistic = -1.8471475468891214, p-value = 0.35731799048980695
# Attempt 1: ADF Statistic = -8.897407289516755, p-value = 1.1965471003271045e-14
# Series is now stationary.
#
# Granger Causality test between AAPL and BBAI:
#
# Granger Causality test between AAPL and SOUN:
#
# Granger Causality test between AAPL and QUBT:
#
# Granger Causality test between AAPL and OKLO:
#
# Granger Causality test between AAPL and RKLB:
#
# Granger Causality test between AAPL and AI:
#
# Granger Causality test between AAPL and AKAM:
#
# Granger Causality test between GOOG and BBAI:
#
# Granger Causality test between GOOG and SOUN:
#
# Granger Causality test between GOOG and QUBT:
#
# Granger Causality test between GOOG and OKLO:
#
# Granger Causality test between GOOG and RKLB:
#
# Granger Causality test between GOOG and AI:
#
# Granger Causality test between GOOG and AKAM:
#
# Granger Causality test between MSFT and BBAI:
#
# Granger Causality test between MSFT and SOUN:
#
# Granger Causality test between MSFT and QUBT:
#
# Granger Causality test between MSFT and OKLO:
#
# Granger Causality test between MSFT and RKLB:
#
# Granger Causality test between MSFT and AI:
#
# Granger Causality test between MSFT and AKAM:
#
# Granger Causality test between NVDA and BBAI:
#
# Granger Causality test between NVDA and SOUN:
#
# Granger Causality test between NVDA and QUBT:
#
# Granger Causality test between NVDA and OKLO:
#
# Granger Causality test between NVDA and RKLB:
#
# Granger Causality test between NVDA and AI:
#
# Granger Causality test between NVDA and AKAM:
#
# Granger Causality test between META and BBAI:
#
# Granger Causality test between META and SOUN:
#
# Granger Causality test between META and QUBT:
#
# Granger Causality test between META and OKLO:
#
# Granger Causality test between META and RKLB:
#
# Granger Causality test between META and AI:
#
# Granger Causality test between META and AKAM:
#
# Granger Causality test between AMZN and BBAI:
#
# Granger Causality test between AMZN and SOUN:
#
# Granger Causality test between AMZN and QUBT:
#
# Granger Causality test between AMZN and OKLO:
#
# Granger Causality test between AMZN and RKLB:
#
# Granger Causality test between AMZN and AI:
#
# Granger Causality test between AMZN and AKAM:
#
# Granger Causality test between TSLA and BBAI:
#
# Granger Causality test between TSLA and SOUN:
#
# Granger Causality test between TSLA and QUBT:
#
# Granger Causality test between TSLA and OKLO:
#
# Granger Causality test between TSLA and RKLB:
#
# Granger Causality test between TSLA and AI:
#
# Granger Causality test between TSLA and AKAM:
#
# ============================== Running for last 720 days ==============================
# [*********************100%***********************]  14 of 14 completed
# Checking maximum differencing for AAPL...
# Attempt 0: ADF Statistic = -1.763671162206232, p-value = 0.39864119478488486
# Attempt 1: ADF Statistic = -10.916477391039296, p-value = 1.0643618528107436e-19
# Series is now stationary.
#
# Checking maximum differencing for GOOG...
# Attempt 0: ADF Statistic = -1.8197774597857923, p-value = 0.3706878774426035
# Attempt 1: ADF Statistic = -11.910132026727554, p-value = 5.320679057119158e-22
# Series is now stationary.
#
# Checking maximum differencing for MSFT...
# Attempt 0: ADF Statistic = -2.0535817466837276, p-value = 0.26358430479915895
# Attempt 1: ADF Statistic = -11.037512227019866, p-value = 5.46991755169715e-20
# Series is now stationary.
#
# Checking maximum differencing for NVDA...
# Attempt 0: ADF Statistic = -1.5259270139952639, p-value = 0.5206488634053015
# Attempt 1: ADF Statistic = -11.43445804159633, p-value = 6.3982123836785115e-21
# Series is now stationary.
#
# Checking maximum differencing for META...
# Attempt 0: ADF Statistic = -1.6167646163743206, p-value = 0.47442588797585183
# Attempt 1: ADF Statistic = -10.409216050066474, p-value = 1.8226280526226215e-18
# Series is now stationary.
#
# Checking maximum differencing for AMZN...
# Attempt 0: ADF Statistic = -1.8256747149223194, p-value = 0.3677914538544597
# Attempt 1: ADF Statistic = -16.10180633501841, p-value = 5.122091740208811e-29
# Series is now stationary.
#
# Checking maximum differencing for TSLA...
# Attempt 0: ADF Statistic = -1.9533828671585314, p-value = 0.30737942907569726
# Attempt 1: ADF Statistic = -11.589313913932404, p-value = 2.8170455315188526e-21
# Series is now stationary.
#
# Checking maximum differencing for BBAI...
# Attempt 0: ADF Statistic = -3.0507019644253908, p-value = 0.0304231698234512
# Series is now stationary.
#
# Checking maximum differencing for SOUN...
# Attempt 0: ADF Statistic = -1.452126719386607, p-value = 0.5570468301294149
# Attempt 1: ADF Statistic = -10.735591175500613, p-value = 2.9046999565512783e-19
# Series is now stationary.
#
# Checking maximum differencing for QUBT...
# Attempt 0: ADF Statistic = -1.6789411496115128, p-value = 0.44199398160081005
# Attempt 1: ADF Statistic = -12.570809302498812, p-value = 2.0061221045447803e-23
# Series is now stationary.
#
# Checking maximum differencing for OKLO...
# Attempt 0: ADF Statistic = -1.3670226518275164, p-value = 0.597979835217782
# Attempt 1: ADF Statistic = -8.584193096662295, p-value = 7.585016971056871e-14
# Series is now stationary.
#
# Checking maximum differencing for RKLB...
# Attempt 0: ADF Statistic = -0.2787992537896038, p-value = 0.9284537834668007
# Attempt 1: ADF Statistic = -11.346717992262866, p-value = 1.0228083451387093e-20
# Series is now stationary.
#
# Checking maximum differencing for AI...
# Attempt 0: ADF Statistic = -2.5735696986240164, p-value = 0.0985838327524588
# Attempt 1: ADF Statistic = -12.257068735786643, p-value = 9.258352977222803e-23
# Series is now stationary.
#
# Checking maximum differencing for AKAM...
# Attempt 0: ADF Statistic = -1.7618361322043554, p-value = 0.3995667369534022
# Attempt 1: ADF Statistic = -12.086079850744085, p-value = 2.1760321956055423e-22
# Series is now stationary.
#
# Granger Causality test between AAPL and BBAI:
#
# Granger Causality test between AAPL and SOUN:
#
# Granger Causality test between AAPL and QUBT:
#
# Granger Causality test between AAPL and OKLO:
#
# Granger Causality test between AAPL and RKLB:
#
# Granger Causality test between AAPL and AI:
#
# Granger Causality test between AAPL and AKAM:
#
# Granger Causality test between GOOG and BBAI:
#
# Granger Causality test between GOOG and SOUN:
#
# Granger Causality test between GOOG and QUBT:
#
# Granger Causality test between GOOG and OKLO:
#
# Granger Causality test between GOOG and RKLB:
#
# Granger Causality test between GOOG and AI:
#
# Granger Causality test between GOOG and AKAM:
#
# Granger Causality test between MSFT and BBAI:
#
# Granger Causality test between MSFT and SOUN:
#
# Granger Causality test between MSFT and QUBT:
#
# Granger Causality test between MSFT and OKLO:
#
# Granger Causality test between MSFT and RKLB:
#
# Granger Causality test between MSFT and AI:
#
# Granger Causality test between MSFT and AKAM:
#
# Granger Causality test between NVDA and BBAI:
#
# Granger Causality test between NVDA and SOUN:
#
# Granger Causality test between NVDA and QUBT:
#
# Granger Causality test between NVDA and OKLO:
#
# Granger Causality test between NVDA and RKLB:
#
# Granger Causality test between NVDA and AI:
#
# Granger Causality test between NVDA and AKAM:
#
# Granger Causality test between META and BBAI:
#
# Granger Causality test between META and SOUN:
#
# Granger Causality test between META and QUBT:
#
# Granger Causality test between META and OKLO:
#
# Granger Causality test between META and RKLB:
#
# Granger Causality test between META and AI:
#
# Granger Causality test between META and AKAM:
#
# Granger Causality test between AMZN and BBAI:
#
# Granger Causality test between AMZN and SOUN:
#
# Granger Causality test between AMZN and QUBT:
#
# Granger Causality test between AMZN and OKLO:
#
# Granger Causality test between AMZN and RKLB:
#
# Granger Causality test between AMZN and AI:
#
# Granger Causality test between AMZN and AKAM:
#
# Granger Causality test between TSLA and BBAI:
#
# Granger Causality test between TSLA and SOUN:
#
# Granger Causality test between TSLA and QUBT:
#
# Granger Causality test between TSLA and OKLO:
#
# Granger Causality test between TSLA and RKLB:
#
# Granger Causality test between TSLA and AI:
#
# Granger Causality test between TSLA and AKAM:
#
# ✅ All results saved to 'all_granger_results.csv'
